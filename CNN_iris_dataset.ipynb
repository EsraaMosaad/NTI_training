# %% [markdown]
# <a href="https://colab.research.google.com/github/EsraaMosaad/NTI_training/blob/main/CNN_iris_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
iris = datasets.load_iris()
X=iris.data[:]
Y=iris.target[:]

np.unique(Y)
X.shape
# Out:
# (150, 4)

# %%
encoder=OneHotEncoder(sparse=False)
y=encoder.fit

# %%
#x_train=X[:75]
#x_test=X[75:]
#y_train=Y[:75]
#y_test=Y[75:]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %% [markdown]
#  ** activation**
#  relue --> Epoch 30/30
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4588 - accuracy: 0.9600 - val_loss: 0.4637 - val_accuracy: 0.7000
# sigmoid -->Epoch 30/30
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0962 - accuracy: 0.3500 - val_loss: 1.1015 - val_accuracy: 0.3000
# **optimizer**
# adam -->Epoch 30/30
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3332 - accuracy: 0.9100 - val_loss: 0.2778 - val_accuracy: 0.9600

# %%
model = Sequential()
model.add(Dense(1024,input_shape=(4,), activation="sigmoid"))
model.add(Dense(512,input_shape=(1024,), activation="sigmoid"))

model.add(Dense(3,input_shape=(50,), activation="softmax"))
model.compile(optimizer='adam',loss= 'sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
results=model.fit(
  x=x_train,
  y=y_train,
  shuffle=True,
  epochs=30,
  validation_data=(x_test,y_test)
)
# Out:
# Epoch 1/30
# 4/4 [==============================] - 1s 72ms/step - loss: 1.8029 - accuracy: 0.2800 - val_loss: 1.2532 - val_accuracy: 0.3800
# Epoch 2/30
# 4/4 [==============================] - 0s 21ms/step - loss: 1.3029 - accuracy: 0.2900 - val_loss: 1.3245 - val_accuracy: 0.3200
# Epoch 3/30
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1523 - accuracy: 0.3700 - val_loss: 1.1752 - val_accuracy: 0.3800
# Epoch 4/30
# 4/4 [==============================] - 0s 27ms/step - loss: 1.1845 - accuracy: 0.3300 - val_loss: 1.1369 - val_accuracy: 0.3000
# Epoch 5/30
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1263 - accuracy: 0.3100 - val_loss: 1.2841 - val_accuracy: 0.3200
# Epoch 6/30
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1634 - accuracy: 0.3600 - val_loss: 1.0740 - val_accuracy: 0.3000
# Epoch 7/30
# ...

# %%
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.legend(['Training','Vaildation'])
plt.title('Training and Validation Losses')
plt.xlabel('epoches')
plt.ylabel('losses')
# Out:
# Text(0, 0.5, 'losses')

# %%
import matplotlib.pyplot as plt
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.legend(['Training','Vaildation'])
plt.title('Training and Validation Accuracy')
plt.xlabel('epoches')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')
